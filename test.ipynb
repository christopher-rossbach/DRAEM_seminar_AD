# %%
# %load_ext autoreload
# %autoreload 2

import argparse
from train_DRAEM import train_on_device, get_parser

# %%
parser = get_parser()
args = parser.parse_args(args=["--obj_id", "0", "--epochs", "10"])
train_on_device(args, ["train_draem", "notebook"])
# Out:
# Loading 219 training images into memory...
# Finished loading training images.
# Loading 5640 anomaly source images into memory...
# Finished loading anomaly source images.
# Loading 132 test images into memory...
# Finishing previous runs because reinit is set to 'default'.
# Finished loading test images into memory.
#  View run <strong style="color:#cdcd00">base_capsule_lr0.0001_bs8_ep10</strong> at: <a href='https://wandb.ai/team-cr/DRAEM_seminar_AD/runs/xqb8x2l0' target="_blank">https://wandb.ai/team-cr/DRAEM_seminar_AD/runs/xqb8x2l0</a><br> View project at: <a href='https://wandb.ai/team-cr/DRAEM_seminar_AD' target="_blank">https://wandb.ai/team-cr/DRAEM_seminar_AD</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251108_223851-xqb8x2l0/logs</code>
# Tracking run with wandb version 0.22.3
# ...
